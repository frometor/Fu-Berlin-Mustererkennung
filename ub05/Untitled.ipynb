# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Dec  1 13:47:56 2015

@author: erik
"""

#%matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
# make plots bigger

plt.rcParams['figure.figsize'] = 16, 16  

#loadData
fishData = pd.read_csv("./fish.txt",delim_whitespace=True, dtype={'names': ('index', 'fish age', 'water temperature','fish length'),
                     'formats': ('i4','i4', 'i4','i4' )},index_col=0, names = [None, 'fish age', 'water temperature','fish length'])
fishData.head()
# Out:
#    fish age  water temperature  fish length
# 1        14                 25          620
# 2        28                 25         1315
# 3        41                 25         2120
# 4        55                 25         2600
# 5        69                 25         3110

# %%
#%matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
# make plots bigger

plt.rcParams['figure.figsize'] = 16, 16  
import pandas as pd


wineDataPath = "./winequality-red.txt"
wineData = pd.read_csv(wineDataPath, delimiter=';',dtype={'names': ('fixed_acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', ' alcohol', 'quality'),
                    }, names = ['fixed_acidity','volatile acidity', 'citric acid','residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', ' alcohol', 'quality'])
print (wineData.shape)
wineData.head()



from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error as mse
x = wineData['fixed_acidity']
y = wineData['quality']

lm = LinearRegression()
lm.fit(x,y)
    
#print('qual',qual)
#npqual=np.array(qual)
#print('npqual',npqual)

#np.reshape(npqual,(1,1599))
#print(npqual.shape)
#features=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']
#feat=wine[features[4]]
#print(feat)
#iters= list(it.combinations(features,1))
#print('iters',iters[0][0])

#feat=wine[iters[0][0]]
#print(wine[iters[0][0]])

#npfeat = np.array(feat)
#print(npfeat.shape)

#np.reshape(npfeat,(1,1599))
#print('npfeatnew',npfeat.shape)
#print('npfeat',npfeat)
#print('npqual',npqual)



print (lm.intercept_)
print (lm.coef_)
# Out:
# (1599, 12)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-749d183be8b8> in <module>()
#      25
#      26 lm = LinearRegression()
# ---> 27 lm.fit(x,y)
#      28
#      29 #print('qual',qual)
#
# /home/erik/anaconda3/lib/python3.4/site-packages/sklearn/linear_model/base.py in fit(self, X, y, n_jobs)
#     374             n_jobs_ = self.n_jobs
#     375         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 376                          y_numeric=True, multi_output=True)
#     377
#     378         X, y, X_mean, y_mean, X_std = self._center_data(
#
# /home/erik/anaconda3/lib/python3.4/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric)
#     452         y = y.astype(np.float64)
#     453
# ...

# %%
from sklearn.linear_model import LinearRegression
y= fishData['fish length']
features = ['water temperature','fish age']
x=fishData[features]
lm = LinearRegression()
lm.fit(x,y)

print (lm.intercept_)
print (lm.coef_)
list =zip(features, lm.coef_)
print(list)
# Out:
# 3904.26601675
# [-106.41363636   26.24068177]
# ...

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Dec  1 12:48:38 2015

@author: erik
"""
import pandas as pd
#from numpy import loadtxt
#lines = loadtxt("winequality-red.txt", comments="#", delimiter=";", unpack=False)
#print(lines)
#qual= lines[:,11]
#print(qual)

wine = pd.read_csv("./winequality-red.txt", delimiter=";",\
dtype={'names':('fixed acidity','volatile acidity',' citric acid',' residual sugar','chlorides;','free sulfur dioxide',' total sulfur dioxide','density','pH','sulphates','alcohol','quality'),\
'formats':('i4','i4','i4','i4','i4','i4','i4','i4','i4','i4','i4','i4','i4')},\
index_col=False,\
names=['fixed acidity','volatile acidity',' citric acid',' residual sugar','chlorides;','free sulfur dioxide',' total sulfur dioxide','density','pH','sulphates','alcohol','quality'])
wine.head(n=5)
# Out:
#    fixed acidity  volatile acidity   citric acid   residual sugar  chlorides;  \
# 0            7.4              0.70          0.00              1.9       0.076
# 1            7.8              0.88          0.00              2.6       0.098
# 2            7.8              0.76          0.04              2.3       0.092
# 3           11.2              0.28          0.56              1.9       0.075
# 4            7.4              0.70          0.00              1.9       0.076
#
#    free sulfur dioxide   total sulfur dioxide  density    pH  sulphates  \
# 0                   11                     34   0.9978  3.51       0.56
# 1                   25                     67   0.9968  3.20       0.68
# 2                   15                     54   0.9970  3.26       0.65
# 3                   17                     60   0.9980  3.16       0.58
# 4                   11                     34   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...
